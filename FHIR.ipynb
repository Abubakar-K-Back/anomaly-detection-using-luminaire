# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import json
# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os

import warnings
warnings.filterwarnings('ignore')

# %%
df= pd.read_json('./data/fhir/hospitalInformation1608676333939.json')

# %%
df
# Out:
#                                                  entry resourceType  \
# 0    {'request': {'method': 'POST', 'url': 'Organiz...       Bundle
# 1    {'request': {'method': 'POST', 'url': 'Organiz...       Bundle
# 2    {'request': {'method': 'POST', 'url': 'Organiz...       Bundle
# 3    {'request': {'method': 'POST', 'url': 'Organiz...       Bundle
# 4    {'request': {'method': 'POST', 'url': 'Organiz...       Bundle
# ..                                                 ...          ...
# 186  {'request': {'method': 'POST', 'url': 'Organiz...       Bundle
# 187  {'request': {'method': 'POST', 'url': 'Organiz...       Bundle
# 188  {'request': {'method': 'POST', 'url': 'Organiz...       Bundle
# 189  {'request': {'method': 'POST', 'url': 'Organiz...       Bundle
# 190  {'request': {'method': 'POST', 'url': 'Organiz...       Bundle
#
#             type
# 0    transaction
# 1    transaction
# 2    transaction
# 3    transaction
# 4    transaction
# ..           ...
# 186  transaction
# 187  transaction
# 188  transaction
# 189  transaction
# 190  transaction
#
# [191 rows x 3 columns]
